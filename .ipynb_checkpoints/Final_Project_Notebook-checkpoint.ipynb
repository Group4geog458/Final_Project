# %%
import geopandas as gpd
import pandas as pd

# %%
def ag_count(state):
    data = gpd.read_file("Data\\SoVI2010_" + state + "\\SoVI0610_" + state + ".shp")
    data['CTFIPS'] = data['STATEFP10'] + data['COUNTYFP10']
    data = data.groupby('CTFIPS').agg({"SOVI0610" + state: "mean", "P0010001": "sum"})
    data.rename(index=str, columns={"SOVI0610" + state: "SOVI"})

CA = ag_count("CA")
FL = ag_count("FL")
IN = ag_count("IN")
LA = ag_count("LA")
ME = ag_count("ME")
WA = ag_count("WA")
CA.head()
# Out:
#          P0010001  SOVI0610CA
# CTFIPS
# 06001   1510271.0   -0.174812
# 06003      1175.0    0.686160
# 06005     38091.0    1.558083
# 06007    220000.0    1.954188
# 06009     45578.0    1.929986

# %%
CA.rename(index=str, columns={"SOVI0610CA": "SOVI"})

# %%
fema = gpd.read_file("Data\\FEMA_6\\FEMA_6.shp")
fema.head()
# Out:
#    OBJECTID STFIPS ST_ABBR CTFIPS       STATE         COUNTY GEO_SUFFIX  \
# 0        14     06      CA  06059  California         Orange     County
# 1        15     06      CA  06103  California         Tehama     County
# 2        16     06      CA  06011  California         Colusa     County
# 3        17     06      CA  06083  California  Santa Barbara     County
# 4        18     06      CA  06051  California           Mono     County
#
#    TOTAL_DECL  FLOOD_1964  ICE_STORM_  ...  COASTAL_2K  TSUNAMI_19  \
# 0          21           8           0  ...           0           0
# 1          12           6           0  ...           0           0
# 2          10           3           0  ...           0           0
# 3          19           8           0  ...           0           0
# 4           5           3           0  ...           0           0
#
#    COASTAL_19  EARTHQUA_1  REGION_NO  Shape_Leng  Winter_196  Shape_Le_1  \
# ...

# %%
data = pd.merge(fema, CA, on="CTFIPS", how="left")
type(data)
#data.sort_values(by='CTFIPS', ascending=False)
#data.head()
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
CA.rename(index=str, columns={"SOVI0610CA": "SOVI"})
sovi
# Out:
#          P0010001  SOVI0610CA  SOVI0610FL
# CTFIPS
# 06001   1510271.0   -0.174812         NaN
# 06003      1175.0    0.686160         NaN
# 06005     38091.0    1.558083         NaN
# 06007    220000.0    1.954188         NaN
# 06009     45578.0    1.929986         NaN
# 06011     21419.0    0.455662         NaN
# 06013   1049025.0   -0.402607         NaN
# 06015     28610.0    3.393793         NaN
# 06017    181058.0   -0.455807         NaN
# 06019    924798.0    1.159163         NaN
# 06021     28122.0    0.474415         NaN
# 06023    134623.0    1.278850         NaN
# 06025    174528.0    2.280297         NaN
# 06027     18546.0    2.365062         NaN
# 06029    828068.0    0.834129         NaN
# 06031    134441.0    0.130759         NaN
# 06033     64665.0    3.061438         NaN
# 06035     34895.0    0.300976         NaN
# 06037   9812386.0    0.235760         NaN
# 06039    150865.0    0.878349         NaN
# 06041    247555.0   -1.472304         NaN
# ...
